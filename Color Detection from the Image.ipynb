# %%
import cv2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
img = cv2.imread('D:\opencv\colours.jpg')

# %%
plt.figure(figsize=(20,8))
plt.imshow(img)

# %%
grid_RGB = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
plt.figure(figsize=(20,8))
plt.imshow(grid_RGB)

# %%
grid_HSV = cv2.cvtColor(grid_RGB, cv2.COLOR_RGB2HSV)

# %%
lower_black = np.array([0,0,0])
upper_black = np.array([250,255,30])

# %%
lower_white = np.array([0,0,255])
upper_white = np.array([0,0,255])

# %%
lower_red = np.array([0,150,50])
upper_red = np.array([10,255,255])

# %%
lower_green = np.array([45,150,50])
upper_green = np.array([65,255,255])

# %%
lower_yellow = np.array([25,150,50])
upper_yellow = np.array([35,255,255])

# %%
lower_light_blue = np.array([95,150,0])
upper_light_blue = np.array([110,255,255])

# %%
lower_orange = np.array([15,150,0])
upper_orange = np.array([25,255,255])

# %%
lower_pink = np.array([145,150,0])
upper_pink = np.array([155,255,255])

# %%
lower_cyan = np.array([85,150,0])
upper_cyan = np.array([95,255,255])

# %%
lower_dark_blue = np.array([110,50,50])
upper_dark_blue = np.array([130,255,255])

# %%
mask_1 = cv2.inRange(grid_HSV, lower_black, upper_black)

# %%
mask_2 = cv2.inRange(grid_HSV, lower_white, upper_white)

# %%
mask_3 = cv2.inRange(grid_HSV, lower_red, upper_red)

# %%
mask_4 = cv2.inRange(grid_HSV, lower_green, upper_green)

# %%
mask_5 = cv2.inRange(grid_HSV, lower_yellow, upper_yellow)

# %%
mask_6 = cv2.inRange(grid_HSV, lower_light_blue, upper_light_blue)

# %%
mask_7 = cv2.inRange(grid_HSV, lower_orange, upper_orange)

# %%
mask_8 = cv2.inRange(grid_HSV, lower_pink, upper_pink)

# %%
mask_9 = cv2.inRange(grid_HSV, lower_cyan, upper_cyan)

# %%
mask_10 = cv2.inRange(grid_HSV, lower_dark_blue, upper_dark_blue)

# %%
sun = eval(input('Choose the color from the image(enter Black:1;White:2;Red:3;Green:4;Yellow:5;Light_blue:6;Orange:7;Pink:8;cyan:9;Dark_blue:10) :'))
if sun == 1:
    plt.figure(figsize=(20,8))
    plt.imshow(mask_1)
if sun == 2:
    plt.figure(figsize=(20,8))
    plt.imshow(mask_2) 
if sun == 3:
    plt.figure(figsize=(20,8))
    plt.imshow(mask_3)
if sun == 4:
    plt.figure(figsize=(20,8))
    plt.imshow(mask_4) 
if sun == 5:
    plt.figure(figsize=(20,8))
    plt.imshow(mask_5)
if sun == 6:
    plt.figure(figsize=(20,8))
    plt.imshow(mask_6) 
if sun == 7:
    plt.figure(figsize=(20,8))
    plt.imshow(mask_7)
if sun == 8:
    plt.figure(figsize=(20,8))
    plt.imshow(mask_8) 
if sun == 9:
    plt.figure(figsize=(20,8))
    plt.imshow(mask_9)
if sun == 10:
    plt.figure(figsize=(20,8))
    plt.imshow(mask_10)
# Out:
# Choose the color from the image(enter Black:1;White:2;Red:3;Green:4;Yellow:5;Light_blue:6;Orange:7;Pink:8;cyan:9;Dark_blue:10) :2

# %%
sun = eval(input('Choose the color from the image(enter Black:1;White:2;Red:3;Green:4;Yellow:5;Light_blue:6;Orange:7;Pink:8;cyan:9;Dark_blue:10) :'))
if sun == 1:
    res = cv2.bitwise_and(grid_RGB, grid_RGB, mask=mask_1)
    plt.figure(figsize=(20,8))
    plt.imshow(res)
if sun == 2:
    res = cv2.bitwise_and(grid_RGB, grid_RGB, mask=mask_2)
    plt.figure(figsize=(20,8))
    plt.imshow(res) 
if sun == 3:
    res = cv2.bitwise_and(grid_RGB, grid_RGB, mask=mask_3)
    plt.figure(figsize=(20,8))
    plt.imshow(res)
if sun == 4:
    res = cv2.bitwise_and(grid_RGB, grid_RGB, mask=mask_4)
    plt.figure(figsize=(20,8))
    plt.imshow(res)
if sun == 5:
    res = cv2.bitwise_and(grid_RGB, grid_RGB, mask=mask_5)
    plt.figure(figsize=(20,8))
    plt.imshow(res)
if sun == 6:
    res = cv2.bitwise_and(grid_RGB, grid_RGB, mask=mask_6)
    plt.figure(figsize=(20,8))
    plt.imshow(res)
if sun == 7:
    res = cv2.bitwise_and(grid_RGB, grid_RGB, mask=mask_7)
    plt.figure(figsize=(20,8))
    plt.imshow(res)
if sun == 8:
    res = cv2.bitwise_and(grid_RGB, grid_RGB, mask=mask_8)
    plt.figure(figsize=(20,8))
    plt.imshow(res)
if sun == 9:
    res = cv2.bitwise_and(grid_RGB, grid_RGB, mask=mask_9)
    plt.figure(figsize=(20,8))
    plt.imshow(res)
if sun == 10:
    res = cv2.bitwise_and(grid_RGB, grid_RGB, mask=mask_10)
    plt.figure(figsize=(20,8))
    plt.imshow(res)
# Out:
# Choose the color from the image(enter Black:1;White:2;Red:3;Green:4;Yellow:5;Light_blue:6;Orange:7;Pink:8;cyan:9;Dark_blue:10) :2
